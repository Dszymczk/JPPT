# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt



# need to pip install xlrd to read csv files
df = pd.read_excel("datasets/pd4.xlsx", sheet_name='Arkusz1')

df
# Out:
#    nazwa parametru        p1        p2        p3        p4        p5  \
# 0               C1  0.897776  1.059293  0.685478  1.020124  1.045547
# 1               C2  0.953501  0.927492  1.717376  0.982511  0.836885
# 2               C3  1.148723  1.013215  0.597146  0.997366  1.117568
# 3              PD1  1.213652  1.111843  0.846536  1.147372  1.058449
# 4              PD2  1.588134  1.398797  1.062807  1.133034  1.668513
# 5              PD3  1.133917  0.822511  1.039155  0.899360  1.512468
# 6               C1  0.612112  0.831776  0.613492  0.821049  0.600423
# 7               C2  0.752452  0.827945  1.196165  0.985487  1.399577
# 8               C3  1.635436  1.340279  1.190343  1.193464 -1.000000
# 9              PD1  1.121830  1.272906 -1.000000  1.222092  1.935619
# 10             PD2  1.370171  1.272767 -1.000000  1.452021  1.589807
# 11             PD3  0.987163  1.112072  0.565962  1.139577 -1.000000
# 12              C1  1.169723  1.032516  0.701321  0.709320  0.575251
# ...

# %%
df_tmp = df[ df['p1'] != -1 ]
df_p1p2 = df_tmp[ df_tmp['p2'] != -1 ]
df_p1p2 = df_p1p2
df_p1p2
#plt.plot(x, y)
# Out:
#    nazwa parametru        p1        p2        p3        p4        p5  \
# 0               C1  0.897776  1.059293  0.685478  1.020124  1.045547
# 1               C2  0.953501  0.927492  1.717376  0.982511  0.836885
# 2               C3  1.148723  1.013215  0.597146  0.997366  1.117568
# 3              PD1  1.213652  1.111843  0.846536  1.147372  1.058449
# 4              PD2  1.588134  1.398797  1.062807  1.133034  1.668513
# 5              PD3  1.133917  0.822511  1.039155  0.899360  1.512468
# 6               C1  0.612112  0.831776  0.613492  0.821049  0.600423
# 7               C2  0.752452  0.827945  1.196165  0.985487  1.399577
# 8               C3  1.635436  1.340279  1.190343  1.193464 -1.000000
# 9              PD1  1.121830  1.272906 -1.000000  1.222092  1.935619
# 10             PD2  1.370171  1.272767 -1.000000  1.452021  1.589807
# 11             PD3  0.987163  1.112072  0.565962  1.139577 -1.000000
# 12              C1  1.169723  1.032516  0.701321  0.709320  0.575251
# ...

# %%
df_p1p2 = df_p1p2.sort_values('p1')
df_p1p2
# Out:
#    nazwa parametru        p1        p2        p3        p4        p5  \
# 6               C1  0.612112  0.831776  0.613492  0.821049  0.600423
# 23             PD3  0.660869  0.619433 -1.000000 -1.000000 -1.000000
# 16             PD2  0.671980  0.926020  0.484276  0.609705  1.138081
# 17             PD3  0.674050  0.768980 -1.000000  0.729721  0.755676
# 15             PD1  0.699136  0.958765  1.366559  1.705203  1.359873
# 26              C3  0.705396  1.044345 -1.000000  0.498367 -1.000000
# 18              C1  0.745781  0.655728 -1.000000 -1.000000 -1.000000
# 7               C2  0.752452  0.827945  1.196165  0.985487  1.399577
# 14              C3  0.812190  0.830411  0.744944  1.273994  1.208975
# 28             PD2  0.894153  1.892801 -1.000000 -1.000000 -1.000000
# 0               C1  0.897776  1.059293  0.685478  1.020124  1.045547
# 19              C2  0.919140  0.952280  1.479398  1.072580 -1.000000
# 1               C2  0.953501  0.927492  1.717376  0.982511  0.836885
# ...

# %%
x = df_p1p2['p1'].to_numpy()
y = df_p1p2['p2'].to_numpy()
plt.plot(x, y)
plt.title("p1(p2)")
plt.savefig('plots/p1_od_p2.png')

# %%
plt.show()
